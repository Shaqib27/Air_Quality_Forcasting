# %%
import pandas as pd
import numpy as np

from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
import pandas as pd

# %%
df = pd.read_csv("clean_air_quality_data.csv")
df.head()
# Out:
#              from_date              to_date   pm25   pm10    no2    nox   nh3  \
# 0  2019-06-20 14:00:00  2019-06-20 15:00:00  33.00  119.5  23.38  18.15  30.5
# 1  2019-06-20 15:00:00  2019-06-20 16:00:00  33.00  120.0  23.38  18.15  30.5
# 2  2019-06-20 16:00:00  2019-06-20 17:00:00  34.50  117.0  23.38  18.15  30.5
# 3  2019-06-20 17:00:00  2019-06-20 18:00:00  41.67  138.0  23.38  18.15  30.5
# 4  2019-06-20 18:00:00  2019-06-20 19:00:00  46.00  143.0  23.38  18.15  30.5
#
#      so2   ozone  benzene  toluene  temperature  wind_speed  wind_direction  \
# 0   7.57  186.32     0.40    64.00        33.97        0.62          172.75
# 1   7.10  191.27     0.40    66.65        33.78        0.62          172.75
# 2  12.00  196.90     0.43    61.30        33.88        0.62          172.75
# 3  12.87  188.53     0.45    62.55        30.75        0.62          172.75
# 4   6.53  168.06     0.35    71.60        29.85        0.62          172.75
#
#    pressure
# 0     741.0
# 1     741.0
# 2     741.0
# 3     741.0
# 4     741.0

# %%
df.dtypes
# Out:
# from_date          object
# to_date            object
# pm25              float64
# pm10              float64
# no2               float64
# nox               float64
# nh3               float64
# so2               float64
# ozone             float64
# benzene           float64
# toluene           float64
# temperature       float64
# wind_speed        float64
# wind_direction    float64
# pressure          float64
# dtype: object

# %%
df['from_date'] = pd.to_datetime(df['from_date'])
df['to_date'] = pd.to_datetime(df['to_date'])

# %%
df.dtypes
# Out:
# from_date         datetime64[ns]
# to_date           datetime64[ns]
# pm25                     float64
# pm10                     float64
# no2                      float64
# nox                      float64
# nh3                      float64
# so2                      float64
# ozone                    float64
# benzene                  float64
# toluene                  float64
# temperature              float64
# wind_speed               float64
# wind_direction           float64
# pressure                 float64
# dtype: object

# %%
df = df.sort_values('from_date')
df = df.set_index('from_date')

# %%
df = df.drop(columns=['to_date'])

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
df['pm25_lag_3']  = df['pm25'].shift(3)
df['pm25_lag_6']  = df['pm25'].shift(6)
df['pm25_lag_24'] = df['pm25'].shift(24)  # same hour yesterday

# %%
df = df.dropna()

# %%
df['pm25_roll_6']  = df['pm25'].rolling(6).mean()
df['pm25_roll_24'] = df['pm25'].rolling(24).mean()

# %%
X_ts = df.drop(columns=['pm25'])
y_ts = df['pm25']

# %%
split_date = pd.to_datetime("2022-01-01")

X_train = X_ts[X_ts.index < split_date]
X_test  = X_ts[X_ts.index >= split_date]

y_train = y_ts[y_ts.index < split_date]
y_test  = y_ts[y_ts.index >= split_date]

# %%
rf_ts = RandomForestRegressor(
    n_estimators=200,
    random_state=42,
    n_jobs=-1
)

rf_ts.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=200, n_jobs=-1, random_state=42)

# %%
y_pred = rf_ts.predict(X_test)

# %%
print("MAE :", mean_absolute_error(y_test, y_pred))
print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred)))
print("R2  :", r2_score(y_test, y_pred))
# Out:
# MAE : 14.77124611263736
# RMSE: 30.552481541500228
# R2  : 0.8207671941970055

# %%
import joblib
joblib.dump(rf_ts, "pm25_random_forest_model11.pkl")
# Out:
# ['pm25_random_forest_model11.pkl']

# %%
pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-3.1.3-py3-none-macosx_12_0_arm64.whl.metadata (2.0 kB)
# Requirement already satisfied: numpy in /Users/mdshaqibhussain/Desktop/EVNS/venv310/lib/python3.10/site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in /Users/mdshaqibhussain/Desktop/EVNS/venv310/lib/python3.10/site-packages (from xgboost) (1.15.3)
# Downloading xgboost-3.1.3-py3-none-macosx_12_0_arm64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 3.2 MB/s  0:00:003.2 MB/s eta 0:00:01:01
# Installing collected packages: xgboost
# Successfully installed xgboost-3.1.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import xgboost as xgb
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
xgb_model = xgb.XGBRegressor(
    n_estimators=300,
    learning_rate=0.05,
    max_depth=6,
    subsample=0.8,
    colsample_bytree=0.8,
    objective='reg:squarederror',
    random_state=42,
    n_jobs=-1
)

# %%
xgb_model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=300,
#              n_jobs=-1, num_parallel_tree=None, ...)

# %%
y_pred_xgb = xgb_model.predict(X_test)

# %%
mae  = mean_absolute_error(y_test, y_pred_xgb)
rmse = np.sqrt(mean_squared_error(y_test, y_pred_xgb))
r2   = r2_score(y_test, y_pred_xgb)

print("XGBoost MAE :", mae)
print("XGBoost RMSE:", rmse)
print("XGBoost R2  :", r2)
# Out:
# XGBoost MAE : 14.020803511639436
# XGBoost RMSE: 26.49240971439282
# XGBoost R2  : 0.8652379997177512

# %%
import joblib
joblib.dump(xgb_model, "pm25_XGBoost_model.pkl")
# Out:
# ['pm25_XGBoost_model.pkl']

# %%
pip install lightgbm
# Out:
# Collecting lightgbm
#   Downloading lightgbm-4.6.0-py3-none-macosx_12_0_arm64.whl.metadata (17 kB)
# Requirement already satisfied: numpy>=1.17.0 in /Users/mdshaqibhussain/Desktop/EVNS/venv310/lib/python3.10/site-packages (from lightgbm) (1.26.4)
# Requirement already satisfied: scipy in /Users/mdshaqibhussain/Desktop/EVNS/venv310/lib/python3.10/site-packages (from lightgbm) (1.15.3)
# Downloading lightgbm-4.6.0-py3-none-macosx_12_0_arm64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 5.0 MB/s  0:00:00m 7.0 MB/s eta 0:00:01
# Installing collected packages: lightgbm
# Successfully installed lightgbm-4.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import lightgbm as lgb
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 import lightgbm as lgb
#       2 import numpy as np
#       3 from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
#
# File ~/Desktop/EVNS/venv310/lib/python3.10/site-packages/lightgbm/__init__.py:11
#       7 from pathlib import Path
#       9 # .basic is intentionally loaded as early as possible, to dlopen() lib_lightgbm.{dll,dylib,so}
#      10 # and its dependencies as early as possible
# ---> 11 from .basic import Booster, Dataset, Sequence, register_logger
#      12 from .callback import EarlyStopException, early_stopping, log_evaluation, record_evaluation, reset_parameter
#      13 from .engine import CVBooster, cv, train
#
# File ~/Desktop/EVNS/venv310/lib/python3.10/site-packages/lightgbm/basic.py:29
#      26 import numpy as np
#      27 import scipy.sparse
# ---> 29 from .compat import (
#      30     CFFI_INSTALLED,
#      31     PANDAS_INSTALLED,
#      32     PYARROW_INSTALLED,
#      33     arrow_cffi,
#      34     arrow_is_boolean,
#      35     arrow_is_floating,
#      36     arrow_is_integer,
#      37     concat,
#      38     dt_DataTable,
#      39     pa_Array,
#      40     pa_chunked_array,
#      41     pa_ChunkedArray,
#      42     pa_compute,
#      43     pa_Table,
#      44     pd_CategoricalDtype,
#      45     pd_DataFrame,
#      46     pd_Series,
#      47 )
#      49 if TYPE_CHECKING:
#      50     from typing import Literal
#
# File ~/Desktop/EVNS/venv310/lib/python3.10/site-packages/lightgbm/compat.py:191
#     189 """matplotlib"""
#     190 try:
# --> 191     import matplotlib  # noqa: F401
#     193     MATPLOTLIB_INSTALLED = True
#     194 except ImportError:
#
# File ~/Desktop/EVNS/venv310/lib/python3.10/site-packages/matplotlib/__init__.py:1299
#    1295     rcParams['backend_fallback'] = False
#    1298 if os.environ.get('MPLBACKEND'):
# -> 1299     rcParams['backend'] = os.environ.get('MPLBACKEND')
#    1302 def get_backend(*, auto_select=True):
#    1303     """
#    1304     Return the name of the current backend.
#    1305
#    (...)
#    1323     matplotlib.use
#    1324     """
#
# File ~/Desktop/EVNS/venv310/lib/python3.10/site-packages/matplotlib/__init__.py:774, in RcParams.__setitem__(self, key, val)
#     772         cval = self.validate[key](val)
#     773     except ValueError as ve:
# --> 774         raise ValueError(f"Key {key}: {ve}") from None
#     775     self._set(key, cval)
#     776 except KeyError as err:
#
# ValueError: Key backend: 'module://matplotlib_inline.backend_inline' is not a valid value for backend; supported values are ['gtk3agg', 'gtk3cairo', 'gtk4agg', 'gtk4cairo', 'macosx', 'nbagg', 'notebook', 'qtagg', 'qtcairo', 'qt5agg', 'qt5cairo', 'tkagg', 'tkcairo', 'webagg', 'wx', 'wxagg', 'wxcairo', 'agg', 'cairo', 'pdf', 'pgf', 'ps', 'svg', 'template']
